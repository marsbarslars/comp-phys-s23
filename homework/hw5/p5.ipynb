# %%
#Import modules
import numpy as np
import numpy.random as rand
import matplotlib.pyplot as plt

x = []
for j in range(10**6):
    i = 0
    u = 0
    while u < 1:
        u += rand.random(1)
        i += 1
    x.append(i)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.hist(x, bins=range(min(x), max(x) + 1, 1))
ax.set(xlabel='X', ylabel='Frequency')
plt.show()

# %%
est = sum(x)/len(x)

print('Estimate: ' + str(est))
print('Real Value: ' + str(np.exp(1)))
print('Percent Error: ' + str((est-np.exp(1))*100/np.exp(1)) + '%')
# Out:
# Estimate: 2.71767
# Real Value: 2.718281828459045
# Percent Error: -0.022507911160628162%

# %%
x = np.array(x)
anti = max(x) - x
e = (x + anti)/2
est = sum(e)/len(e)

print('New estimate: ' + str(est))
print('Percent Error: ' + str((est-np.exp(1))*100/np.exp(1)) + '%')
# Out:
# New estimate: 5.0
# Percent Error: 83.93972058572118%
